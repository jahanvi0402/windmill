# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
# %matplotlib inline

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#   tracking_id             datetime  wind_speed(m/s)  \
# 0    WM_33725  2019-08-04 14:33:20        94.820023
# 1      WM_698  2018-11-05 10:13:20       241.832734
# 2    WM_39146  2019-09-14 14:03:20        95.484724
# 3     WM_6757  2018-12-25 15:33:20       238.819424
# 4    WM_21521  2019-05-04 03:13:20        10.722890
#
#    atmospheric_temperature(°C)  shaft_temperature(°C)  blades_angle(°)  \
# 0                   -99.000000              41.723019        -0.903423
# 1                    27.764785             -99.000000       -99.000000
# 2                          NaN              41.855473        12.652763
# 3                   -99.000000              45.443914        15.115323
# 4                          NaN              41.981183         1.715696
#
#    gearbox_temperature(°C)  engine_temperature(°C)  motor_torque(N-m)  \
# 0                82.410573               42.523015        2563.124522
# 1                44.104919               46.258870        2372.384119
# ...

# %%
df.shape
# Out:
# (28200, 22)

# %%
df.isna().sum()
# Out:
# tracking_id                          0
# datetime                             0
# wind_speed(m/s)                    273
# atmospheric_temperature(°C)       3450
# shaft_temperature(°C)                2
# blades_angle(°)                    216
# gearbox_temperature(°C)              1
# engine_temperature(°C)              12
# motor_torque(N-m)                   24
# generator_temperature(°C)           12
# atmospheric_pressure(Pascal)      2707
# area_temperature(°C)                 0
# windmill_body_temperature(°C)     2363
# wind_direction(°)                 5103
# resistance(ohm)                      1
# rotor_torque(N-m)                  572
# turbine_status                    1759
# cloud_level                        276
# blade_length(m)                   5093
# blade_breadth(m)                     0
# windmill_height(m)                 543
# windmill_generated_power(kW/h)     207
# dtype: int64

# %%
for i in list(df.columns):
    if df[i].dtypes == "float":
        df[i].fillna(df[i].mean(), inplace = True)

# %%
df["cloud_level"].fillna("Low", inplace = True)
df["turbine_status"].fillna("B2", inplace = True)

# %%
corr = df.corr()
plt.figure(figsize=(20,10))
mask = np.zeros_like(corr,dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr,mask=mask,annot=True)
plt.show()

# %% [markdown]
# ### PLOTING

# %%
x_p = ['tracking_id', 'datetime', 'wind_speed(m/s)','atmospheric_temperature(°C)', 'shaft_temperature(°C)',
       'blades_angle(°)', 'gearbox_temperature(°C)', 'engine_temperature(°C)','motor_torque(N-m)', 'generator_temperature(°C)',
       'atmospheric_pressure(Pascal)', 'area_temperature(°C)','windmill_body_temperature(°C)', 'wind_direction(°)', 'resistance(ohm)',
       'rotor_torque(N-m)', 'turbine_status', 'cloud_level', 'blade_length(m)','blade_breadth(m)',
       'windmill_height(m)']
y_p = df['windmill_generated_power(kW/h)']
len(x_p)
# Out:
# 21

# %% [markdown]
# Blue: Medium, Orange: Low, Green: Extremly Low

# %% [markdown]
# Col 2

# %%
sns.scatterplot(x = df[x_p[2]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='wind_speed(m/s)', ylabel='windmill_generated_power(kW/h)'>

# %%
m = df[(df[x_p[2]]>-350) & (df[x_p[2]]<480)][x_p[2]].mean()
def sub(s):
    if (s<-350 or s>480):
        return m
    else:
        return s
df[x_p[2]] = df[x_p[2]].apply(sub)

# %%
sns.scatterplot(x = df[x_p[2]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='wind_speed(m/s)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 3

# %%
sns.scatterplot(x = df[x_p[3]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='atmospheric_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %%
m = df[(df[x_p[3]]>-30) & (df[x_p[3]]<70)][x_p[3]].mean()
def sub(s):
    if (s<-30 or s>70):
        return m
    else:
        return s
df[x_p[3]] = df[x_p[3]].apply(sub)

# %%
sns.scatterplot(x = df[x_p[3]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='atmospheric_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 4

# %%
sns.scatterplot(x = df[x_p[4]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='shaft_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %%
m = df[(df[x_p[4]]>-80) & (df[x_p[4]]<120)][x_p[4]].mean()
def sub(s):
    if (s<-80 or s>140):
        return m
    else:
        return s
df[x_p[4]] = df[x_p[4]].apply(sub)

# %%
sns.scatterplot(x = df[x_p[4]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='shaft_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 5

# %%
sns.scatterplot(x = df[x_p[5]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='blades_angle(°)', ylabel='windmill_generated_power(kW/h)'>

# %%
m = df[(df[x_p[5]]>-80) & (df[x_p[5]]<120)][x_p[5]].mean()
def sub(s):
    if (s<-80 or s>120):
        return m
    else:
        return s
df[x_p[5]] = df[x_p[5]].apply(sub)

# %%
sns.scatterplot(x = df[x_p[5]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='blades_angle(°)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 6

# %%
sns.scatterplot(x = df[x_p[6]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='gearbox_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %%
m = df[(df[x_p[6]]>-200) & (df[x_p[6]]<300)][x_p[6]].mean()
def sub(s):
    if (s<-200 or s>300):
        return m
    else:
        return s
df[x_p[6]] = df[x_p[6]].apply(sub)

# %%
sns.scatterplot(x = df[x_p[6]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='gearbox_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 7

# %%
sns.scatterplot(x = df[x_p[7]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='engine_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 8

# %%
sns.scatterplot(x = df[x_p[8]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='motor_torque(N-m)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 9

# %%
sns.scatterplot(x = df[x_p[9]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='generator_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 10

# %%
sns.scatterplot(x = df[x_p[10]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='atmospheric_pressure(Pascal)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 11

# %%
sns.scatterplot(x = df[x_p[11]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='area_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %%
m = df[(df[x_p[11]]>-5)][x_p[11]].mean()
def sub(s):
    if (s<5):
        return m
    else:
        return s
df[x_p[11]] = df[x_p[11]].apply(sub)

# %%
sns.scatterplot(x = df[x_p[11]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='area_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 12

# %%
sns.scatterplot(x = df[x_p[12]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='windmill_body_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %%
m = df[(df[x_p[12]]>-80) & (df[x_p[12]]<200)][x_p[12]].mean()
def sub(s):
    if (s<-80 or s>200):
        return m
    else:
        return s
df[x_p[12]] = df[x_p[12]].apply(sub)

# %%
sns.scatterplot(x = df[x_p[12]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='windmill_body_temperature(°C)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 13

# %%
sns.scatterplot(x = df[x_p[13]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='wind_direction(°)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 14

# %%
sns.scatterplot(x = df[x_p[14]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='resistance(ohm)', ylabel='windmill_generated_power(kW/h)'>

# %%
m = df[(df[x_p[14]]>-80) & (df[x_p[14]]<3200)][x_p[14]].mean()
def sub(s):
    if (s<-80 or s>3200):
        return m
    else:
        return s
df[x_p[14]] = df[x_p[14]].apply(sub)

# %%
sns.scatterplot(x = df[x_p[14]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='resistance(ohm)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 15

# %%
sns.scatterplot(x = df[x_p[15]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='rotor_torque(N-m)', ylabel='windmill_generated_power(kW/h)'>

# %%
m = df[(df[x_p[15]]!=-99) & (df[x_p[15]]<180)][x_p[15]].mean()
def sub(s):
    if (s==-99.0 or s>180):
        return m
    else:
        return s
df[x_p[15]] = df[x_p[15]].apply(sub)

# %%
sns.scatterplot(x = df[x_p[15]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='rotor_torque(N-m)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 18

# %%
sns.scatterplot(x = df[x_p[18]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='blade_length(m)', ylabel='windmill_generated_power(kW/h)'>

# %%
m = df[(df[x_p[18]]>-6) & (df[x_p[18]]<13)][x_p[18]].mean()
def sub(s):
    if (s<-6 or s>13):
        return m
    else:
        return s
df[x_p[18]] = df[x_p[18]].apply(sub)

# %%
sns.scatterplot(x = df[x_p[18]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='blade_length(m)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 19

# %%
sns.scatterplot(x = df[x_p[19]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='blade_breadth(m)', ylabel='windmill_generated_power(kW/h)'>

# %% [markdown]
# Col 20

# %%
sns.scatterplot(x = df[x_p[20]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='windmill_height(m)', ylabel='windmill_generated_power(kW/h)'>

# %%
m = df[(df[x_p[20]]>-22) & (df[x_p[20]]<70)][x_p[20]].mean()
def sub(s):
    if (s<-22 or s>70):
        return m
    else:
        return s
df[x_p[20]] = df[x_p[20]].apply(sub)

# %%
sns.scatterplot(x = df[x_p[20]], y = y_p, data = df, hue = df[x_p[17]], legend = False)
# Out:
# <AxesSubplot:xlabel='windmill_height(m)', ylabel='windmill_generated_power(kW/h)'>

# %%
for i in ['turbine_status', 'cloud_level']:
    df[i+"_encoded"] = LabelEncoder().fit_transform(df[i])
    del df[i]

# %%
#df.columns
x_val = ['wind_speed(m/s)',
       'atmospheric_temperature(°C)', 'shaft_temperature(°C)',
       'blades_angle(°)', 'gearbox_temperature(°C)', 'engine_temperature(°C)',
       'motor_torque(N-m)', 'generator_temperature(°C)',
       'atmospheric_pressure(Pascal)', 'area_temperature(°C)',
       'windmill_body_temperature(°C)', 'wind_direction(°)', 'resistance(ohm)',
       'rotor_torque(N-m)', 'blade_length(m)', 'blade_breadth(m)',
       'windmill_height(m)','turbine_status_encoded', 'cloud_level_encoded']

# %%
X, y = df[x_val],df[ 'windmill_generated_power(kW/h)']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .25, random_state=0)

# %%
"""from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
y_train_pred = rf.predict(X_train)
y_test_pred = rf.predict(X_test)
print(r2_score(y_train,y_train_pred))
print(r2_score(y_test,y_test_pred))"""
# Out:
# 'from sklearn.ensemble import RandomForestRegressor\nrf = RandomForestRegressor()\nrf.fit(X_train,y_train)\ny_train_pred = rf.predict(X_train)\ny_test_pred = rf.predict(X_test)\nprint(r2_score(y_train,y_train_pred))\nprint(r2_score(y_test,y_test_pred))'

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb_model = GradientBoostingRegressor(criterion='mse',random_state=0,max_depth=5,
                                     n_estimators=500,min_samples_split=2,min_samples_leaf=2)
gb_model.fit(X_train,y_train)
y_train_pred = gb_model.predict(X_train)
y_test_pred = gb_model.predict(X_test)
print(r2_score(y_train,y_train_pred))
print(r2_score(y_test,y_test_pred))
# Out:
# 0.9847695714461678
# 0.9492621143859277
